# %%
import pandas as pd
import requests

# %%
my_key = "tx853dy4upmq6x65qcnc8cw6"

walmart_store = "http://api.walmartlabs.com/v1/stores?apiKey=" + my_key + "&zip=99501"
# This one grabs the store...

walmart_trend_items = "http://api.walmartlabs.com/v1/trends?apiKey=" + my_key
# This one grabs trending items...

walmart_product = "http://api.walmartlabs.com/v1/items/263612249081224994?apiKey=" + my_key

walmart_taxonomy = "http://api.walmartlabs.com/v1/taxonomy?apiKey=" + my_key

r = requests.get(walmart_store)

# %%
type(r)
# Out:
# requests.models.Response

# %%
r.headers
# Out:
# {'Content-Type': 'application/json; charset=utf-8', 'Date': 'Thu, 12 Apr 2018 15:18:30 GMT', 'Server': 'Mashery Proxy', 'X-Mashery-Responder': 'prod-j-worker-us-west-1b-01.mashery.com', 'Content-Length': '1585', 'Connection': 'keep-alive'}

# %%
df = pd.DataFrame(r.json())

# %%
df
# Out:
#           city               coordinates country  \
# 0    Anchorage  [-149.879549, 61.192213]      US
# 1    Anchorage  [-149.743184, 61.211988]      US
# 2    Anchorage  [-149.858952, 61.140889]      US
# 3    Anchorage  [-149.869863, 61.140195]      US
# 4  Eagle River  [-149.535439, 61.309037]      US
# 5      Wasilla  [-149.365105, 61.568719]      US
#
#                                     name    no     phoneNumber stateProvCode  \
# 0          Anchorage Walmart Supercenter  2070  (907) 563-5900            AK
# 1          Anchorage Walmart Supercenter  4359  (907) 339-9039            AK
# 2  Anchorage Walmart Neighborhood Market  7809  (907) 522-2333            AK
# 3          Anchorage Walmart Supercenter  2071  (907) 344-5300            AK
# 4        Eagle River Walmart Supercenter  2188  (907) 694-9780            AK
# 5            Wasilla Walmart Supercenter  2074  (907) 376-9780            AK
#
#                  streetAddress  sundayOpen timezone    zip
# 0                    3101 A St        True     AKST  99503
# 1             7405 Debarr Road        True     AKST  99504
# 2         8801 Old Seward Hwy.       False     AKST  99515
# 3          8900 Old Seward Hwy        True     AKST  99515
# 4         18600 Eagle River Rd        True     AKST  99577
# 5  1350 S Seward Meridian Pkwy        True     AKST  99654
